# %% [markdown]
# ### Importing necessary libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px
from plotly.subplots import make_subplots
from datetime import datetime

# %% [markdown]
# ### Importing dataset

# %%
data = pd.read_csv(r"C:\Users\sv833\Documents\_Projects\Video Game Sales Analysis\vgsales.csv")

# %%
data.head()
# Out:
#    Rank                      Name Platform    Year         Genre Publisher  \
# 0     1                Wii Sports      Wii  2006.0        Sports  Nintendo
# 1     2         Super Mario Bros.      NES  1985.0      Platform  Nintendo
# 2     3            Mario Kart Wii      Wii  2008.0        Racing  Nintendo
# 3     4         Wii Sports Resort      Wii  2009.0        Sports  Nintendo
# 4     5  Pokemon Red/Pokemon Blue       GB  1996.0  Role-Playing  Nintendo
#
#    NA_Sales  EU_Sales  JP_Sales  Other_Sales  Global_Sales
# 0     41.49     29.02      3.77         8.46         82.74
# 1     29.08      3.58      6.81         0.77         40.24
# 2     15.85     12.88      3.79         3.31         35.82
# 3     15.75     11.01      3.28         2.96         33.00
# 4     11.27      8.89     10.22         1.00         31.37

# %%
data.tail()
# Out:
#         Rank                                              Name Platform  \
# 16593  16596                Woody Woodpecker in Crazy Castle 5      GBA
# 16594  16597                     Men in Black II: Alien Escape       GC
# 16595  16598  SCORE International Baja 1000: The Official Game      PS2
# 16596  16599                                        Know How 2       DS
# 16597  16600                                  Spirits & Spells      GBA
#
#          Year     Genre   Publisher  NA_Sales  EU_Sales  JP_Sales  \
# 16593  2002.0  Platform       Kemco      0.01      0.00       0.0
# 16594  2003.0   Shooter  Infogrames      0.01      0.00       0.0
# 16595  2008.0    Racing  Activision      0.00      0.00       0.0
# 16596  2010.0    Puzzle    7G//AMES      0.00      0.01       0.0
# 16597  2003.0  Platform     Wanadoo      0.01      0.00       0.0
#
#        Other_Sales  Global_Sales
# 16593          0.0          0.01
# 16594          0.0          0.01
# 16595          0.0          0.01
# 16596          0.0          0.01
# 16597          0.0          0.01

# %%
data.shape
# Out:
# (16598, 11)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 16598 entries, 0 to 16597
# Data columns (total 11 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Rank          16598 non-null  int64
#  1   Name          16598 non-null  object
#  2   Platform      16598 non-null  object
#  3   Year          16327 non-null  float64
#  4   Genre         16598 non-null  object
#  5   Publisher     16540 non-null  object
#  6   NA_Sales      16598 non-null  float64
#  7   EU_Sales      16598 non-null  float64
#  8   JP_Sales      16598 non-null  float64
#  9   Other_Sales   16598 non-null  float64
#  10  Global_Sales  16598 non-null  float64
# dtypes: float64(6), int64(1), object(4)
# memory usage: 1.4+ MB

# %%
data.describe()
# Out:
#                Rank          Year      NA_Sales      EU_Sales      JP_Sales  \
# count  16598.000000  16327.000000  16598.000000  16598.000000  16598.000000
# mean    8300.605254   2006.406443      0.264667      0.146652      0.077782
# std     4791.853933      5.828981      0.816683      0.505351      0.309291
# min        1.000000   1980.000000      0.000000      0.000000      0.000000
# 25%     4151.250000   2003.000000      0.000000      0.000000      0.000000
# 50%     8300.500000   2007.000000      0.080000      0.020000      0.000000
# 75%    12449.750000   2010.000000      0.240000      0.110000      0.040000
# max    16600.000000   2020.000000     41.490000     29.020000     10.220000
#
#         Other_Sales  Global_Sales
# count  16598.000000  16598.000000
# mean       0.048063      0.537441
# std        0.188588      1.555028
# min        0.000000      0.010000
# 25%        0.000000      0.060000
# 50%        0.010000      0.170000
# 75%        0.040000      0.470000
# max       10.570000     82.740000

# %% [markdown]
# ### Checking for null values

# %%
data.duplicated().sum()
# Out:
# 0

# %%
data.drop_duplicates(inplace=True)
print(data.duplicated().sum())
data.isnull().sum()
# Out:
# 0
# Rank              0
# Name              0
# Platform          0
# Year            271
# Genre             0
# Publisher        58
# NA_Sales          0
# EU_Sales          0
# JP_Sales          0
# Other_Sales       0
# Global_Sales      0
# dtype: int64

# %%
data.shape
# Out:
# (16598, 11)

# %%
data.nunique()
# Out:
# Rank            16598
# Name            11493
# Platform           31
# Year               39
# Genre              12
# Publisher         578
# NA_Sales          409
# EU_Sales          305
# JP_Sales          244
# Other_Sales       157
# Global_Sales      623
# dtype: int64

# %%
data.isnull().any()
# Out:
# Rank            False
# Name            False
# Platform        False
# Year             True
# Genre           False
# Publisher        True
# NA_Sales        False
# EU_Sales        False
# JP_Sales        False
# Other_Sales     False
# Global_Sales    False
# dtype: bool

# %%
data.isnull().sum()
# Out:
# Rank              0
# Name              0
# Platform          0
# Year            271
# Genre             0
# Publisher        58
# NA_Sales          0
# EU_Sales          0
# JP_Sales          0
# Other_Sales       0
# Global_Sales      0
# dtype: int64

# %%
def num_of_null_val_nd_percentage(df):
    values = data.isnull().sum().sort_values(ascending = False)
    percent = (data.isnull().sum() / data.isnull().count()).sort_values(ascending = False)
    total = pd.concat([values, percent], axis = 1, keys = ['Total Values', 'Percentage'])
    return total
num_of_null_val_nd_percentage(data)
# Out:
#               Total Values  Percentage
# Year                   271    0.016327
# Publisher               58    0.003494
# Rank                     0    0.000000
# Name                     0    0.000000
# Platform                 0    0.000000
# Genre                    0    0.000000
# NA_Sales                 0    0.000000
# EU_Sales                 0    0.000000
# JP_Sales                 0    0.000000
# Other_Sales              0    0.000000
# Global_Sales             0    0.000000

# %%
import missingno as msno
msno.bar(data, figsize=(6, 3), color='blue')
# Out:
# <Axes: >

# %%
data.Genre.value_counts()
# Out:
# Action          3316
# Sports          2346
# Misc            1739
# Role-Playing    1488
# Shooter         1310
# Adventure       1286
# Racing          1249
# Platform         886
# Simulation       867
# Fighting         848
# Strategy         681
# Puzzle           582
# Name: Genre, dtype: int64

# %%
cat_col = []
num_col= []
for i in data.columns:
    if data[i].dtype == 'object':
        cat_col.append(i)
    else:
        num_col.append(i)

# %%
print("Categorical Columns :", cat_col)
print("Numerical Columns :", num_col)
# Out:
# Categorical Columns : ['Name', 'Platform', 'Genre', 'Publisher']
# Numerical Columns : ['Rank', 'Year', 'NA_Sales', 'EU_Sales', 'JP_Sales', 'Other_Sales', 'Global_Sales']

# %%
data.columns
# Out:
# Index(['Rank', 'Name', 'Platform', 'Year', 'Genre', 'Publisher', 'NA_Sales',
#        'EU_Sales', 'JP_Sales', 'Other_Sales', 'Global_Sales'],
#       dtype='object')

# %% [markdown]
# ### Filling the null values using mean

# %%
data.Year.fillna(data.Year.median(), inplace = True)

# %%
data.isnull().sum()
# Out:
# Rank             0
# Name             0
# Platform         0
# Year             0
# Genre            0
# Publisher       58
# NA_Sales         0
# EU_Sales         0
# JP_Sales         0
# Other_Sales      0
# Global_Sales     0
# dtype: int64

# %% [markdown]
# ### Dropping the unwanted columns

# %%
data.drop(['Publisher'], inplace = True, axis = 1)

# %%
data.head()
# Out:
#    Rank                      Name Platform    Year         Genre  NA_Sales  \
# 0     1                Wii Sports      Wii  2006.0        Sports     41.49
# 1     2         Super Mario Bros.      NES  1985.0      Platform     29.08
# 2     3            Mario Kart Wii      Wii  2008.0        Racing     15.85
# 3     4         Wii Sports Resort      Wii  2009.0        Sports     15.75
# 4     5  Pokemon Red/Pokemon Blue       GB  1996.0  Role-Playing     11.27
#
#    EU_Sales  JP_Sales  Other_Sales  Global_Sales
# 0     29.02      3.77         8.46         82.74
# 1      3.58      6.81         0.77         40.24
# 2     12.88      3.79         3.31         35.82
# 3     11.01      3.28         2.96         33.00
# 4      8.89     10.22         1.00         31.37

# %%
data.isnull().sum()
# Out:
# Rank            0
# Name            0
# Platform        0
# Year            0
# Genre           0
# NA_Sales        0
# EU_Sales        0
# JP_Sales        0
# Other_Sales     0
# Global_Sales    0
# dtype: int64

# %%
data.describe(exclude = 'object')
# Out:
#                Rank          Year      NA_Sales      EU_Sales      JP_Sales  \
# count  16598.000000  16598.000000  16598.000000  16598.000000  16598.000000
# mean    8300.605254   2006.416134      0.264667      0.146652      0.077782
# std     4791.853933      5.781686      0.816683      0.505351      0.309291
# min        1.000000   1980.000000      0.000000      0.000000      0.000000
# 25%     4151.250000   2003.000000      0.000000      0.000000      0.000000
# 50%     8300.500000   2007.000000      0.080000      0.020000      0.000000
# 75%    12449.750000   2010.000000      0.240000      0.110000      0.040000
# max    16600.000000   2020.000000     41.490000     29.020000     10.220000
#
#         Other_Sales  Global_Sales
# count  16598.000000  16598.000000
# mean       0.048063      0.537441
# std        0.188588      1.555028
# min        0.000000      0.010000
# 25%        0.000000      0.060000
# 50%        0.010000      0.170000
# 75%        0.040000      0.470000
# max       10.570000     82.740000

# %%
plt.bar(data['Global_Sales'],data['Other_Sales'] )
plt.xlabel('Global_sales')
plt.ylabel('Other_sales')
plt.title('Global_Sales acoording to the Other_Sales')
plt.show()

# %%
plt.bar(data['Global_Sales'],data['JP_Sales'] )
plt.xlabel('Global_Sales')
plt.ylabel('JP_Sales')
plt.title('Global_Sales according to the JP_Sales')
plt.show()

# %%
plt.bar(data['NA_Sales'],data['EU_Sales'] )
plt.xlabel('NA_Sales')
plt.ylabel('tEU_Sales')
plt.title('NA_Sales according to the EU_Sales')
plt.show()

# %%
plt.bar(data['Year'],data['Global_Sales'] )
plt.xlabel('Year')
plt.ylabel('Global_Sales')
plt.title('Yearly Global_Sales')
plt.show()

# %%
plt.bar(data['Global_Sales'],data['NA_Sales'] )
plt.xlabel('Global_sales')
plt.ylabel('NA_sales')
plt.title('Global_Sales acoording to the NA_Sales')
plt.show()

# %%
# Bar plot for Global Sales by Top 10 Games
top_10_games = data.nlargest(10, 'Global_Sales')

plt.figure(figsize=(12, 8))
sns.barplot(x='Global_Sales', y='Name', data=top_10_games, palette='viridis')
plt.title('Top 10 Games by Global Sales')
plt.xlabel('Global Sales (in millions)')
plt.ylabel('Game')
plt.show()

# %%
# Pie chart for Sales Distribution by Region for the Top-Selling Game
top_selling_game = data.iloc[0][['NA_Sales', 'EU_Sales', 'JP_Sales', 'Other_Sales']]

plt.figure(figsize=(8, 8))
top_selling_game.plot.pie(autopct='%1.1f%%', startangle=90, colors=['lightblue','orange','blue','yellow'])
plt.title(f'Sales Distribution by Region for {data.iloc[0]["Name"]}')
plt.ylabel('')
plt.show()

# %%
# Histogram for Distribution of Global Sales
plt.figure(figsize=(10, 6))
sns.histplot(data['Global_Sales'], bins=30, kde=True, color='blue')
plt.title('Distribution of Global Sales')
plt.xlabel('Global Sales (in millions)')
plt.ylabel('Frequency')
plt.show()

# %%
# Scatter plot for Year vs Global Sales
plt.figure(figsize=(12, 8))
sns.scatterplot(x='Year', y='Global_Sales', data=data, hue='Genre', palette='Set1', s=100)
plt.title('Year vs Global Sales')
plt.xlabel('Year')
plt.ylabel('Global Sales (in millions)')
plt.legend(title='Genre', bbox_to_anchor=(1.05, 1), loc='upper left')
plt.show()

# %%
# Line plot for Global Sales Over Time
sales_over_time = data.groupby('Year')['Global_Sales'].sum().reset_index()

plt.figure(figsize=(12, 8))
sns.lineplot(x='Year', y='Global_Sales', data=sales_over_time, marker='o')
plt.title('Global Sales Over Time')
plt.xlabel('Year')
plt.ylabel('Global Sales (in millions)')
plt.show()

# %%
plt.hist(data['Other_Sales'])
# Out:
# (array([1.6528e+04, 5.4000e+01, 1.1000e+01, 2.0000e+00, 0.0000e+00,
#         0.0000e+00, 0.0000e+00, 1.0000e+00, 1.0000e+00, 1.0000e+00]),
#  array([ 0.   ,  1.057,  2.114,  3.171,  4.228,  5.285,  6.342,  7.399,
#          8.456,  9.513, 10.57 ]),
#  <BarContainer object of 10 artists>)

# %%
plt.hist(data['Global_Sales'])
# Out:
# (array([1.6516e+04, 5.9000e+01, 1.3000e+01, 7.0000e+00, 2.0000e+00,
#         0.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00, 1.0000e+00]),
#  array([1.0000e-02, 8.2830e+00, 1.6556e+01, 2.4829e+01, 3.3102e+01,
#         4.1375e+01, 4.9648e+01, 5.7921e+01, 6.6194e+01, 7.4467e+01,
#         8.2740e+01]),
#  <BarContainer object of 10 artists>)

# %%
sns.scatterplot(data['Global_Sales'])
# Out:
# <Axes: ylabel='Global_Sales'>

# %%
sns.scatterplot(data['Other_Sales'])
# Out:
# <Axes: ylabel='Other_Sales'>

# %%
# Box plot for Sales by Region
plt.figure(figsize=(10, 6))
sales_columns = ['NA_Sales', 'EU_Sales', 'JP_Sales', 'Other_Sales']
data_melted = data.melt(id_vars='Name', value_vars=sales_columns, var_name='Region', value_name='Sales')

sns.boxplot(x='Region', y='Sales', data=data_melted, palette='Set3')
plt.title('Sales by Region')
plt.xlabel('Region')
plt.ylabel('Sales (in millions)')
plt.show()

# %%
sns.lineplot(x="Year",y="Global_Sales",data=data,ci=None)
# Out:
# C:\Users\sv833\AppData\Local\Temp\ipykernel_20060\4006848982.py:1: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=None` for the same effect.
#
#   sns.lineplot(x="Year",y="Global_Sales",data=data,ci=None)
# <Axes: xlabel='Year', ylabel='Global_Sales'>

# %%
sns.lineplot(x="Global_Sales",y="NA_Sales",data=data,ci=None)
# Out:
# C:\Users\sv833\AppData\Local\Temp\ipykernel_20060\2077884118.py:1: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=None` for the same effect.
#
#   sns.lineplot(x="Global_Sales",y="NA_Sales",data=data,ci=None)
# <Axes: xlabel='Global_Sales', ylabel='NA_Sales'>

# %%
sns.relplot(x="Global_Sales",y="JP_Sales",data=data)

# %%
sns.relplot(x="Global_Sales",y="EU_Sales",data=data)

# %%
sns.relplot(x="Global_Sales",y="NA_Sales",data=data)

# %%
sns.pairplot(data,diag_kind='kde')

# %%
# Heatmap for Correlation Matrix
plt.figure(figsize=(10, 6))
correlation_matrix = data[['NA_Sales', 'EU_Sales', 'JP_Sales', 'Other_Sales', 'Global_Sales']].corr()

sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', linewidths=0.5)
plt.title('Correlation Matrix')
plt.show()

# %%
data.head()
# Out:
#    Rank                      Name Platform    Year         Genre  NA_Sales  \
# 0     1                Wii Sports      Wii  2006.0        Sports     41.49
# 1     2         Super Mario Bros.      NES  1985.0      Platform     29.08
# 2     3            Mario Kart Wii      Wii  2008.0        Racing     15.85
# 3     4         Wii Sports Resort      Wii  2009.0        Sports     15.75
# 4     5  Pokemon Red/Pokemon Blue       GB  1996.0  Role-Playing     11.27
#
#    EU_Sales  JP_Sales  Other_Sales  Global_Sales
# 0     29.02      3.77         8.46         82.74
# 1      3.58      6.81         0.77         40.24
# 2     12.88      3.79         3.31         35.82
# 3     11.01      3.28         2.96         33.00
# 4      8.89     10.22         1.00         31.37

# %% [markdown]
# # FEATURE EXTRACTION

# %%
data.head()
# Out:
#    Rank                      Name Platform    Year         Genre  NA_Sales  \
# 0     1                Wii Sports      Wii  2006.0        Sports     41.49
# 1     2         Super Mario Bros.      NES  1985.0      Platform     29.08
# 2     3            Mario Kart Wii      Wii  2008.0        Racing     15.85
# 3     4         Wii Sports Resort      Wii  2009.0        Sports     15.75
# 4     5  Pokemon Red/Pokemon Blue       GB  1996.0  Role-Playing     11.27
#
#    EU_Sales  JP_Sales  Other_Sales  Global_Sales
# 0     29.02      3.77         8.46         82.74
# 1      3.58      6.81         0.77         40.24
# 2     12.88      3.79         3.31         35.82
# 3     11.01      3.28         2.96         33.00
# 4      8.89     10.22         1.00         31.37

# %%
x = data.iloc[:,0:9]
x.head()
# Out:
#    Rank                      Name Platform    Year         Genre  NA_Sales  \
# 0     1                Wii Sports      Wii  2006.0        Sports     41.49
# 1     2         Super Mario Bros.      NES  1985.0      Platform     29.08
# 2     3            Mario Kart Wii      Wii  2008.0        Racing     15.85
# 3     4         Wii Sports Resort      Wii  2009.0        Sports     15.75
# 4     5  Pokemon Red/Pokemon Blue       GB  1996.0  Role-Playing     11.27
#
#    EU_Sales  JP_Sales  Other_Sales
# 0     29.02      3.77         8.46
# 1      3.58      6.81         0.77
# 2     12.88      3.79         3.31
# 3     11.01      3.28         2.96
# 4      8.89     10.22         1.00

# %%
y = data['Global_Sales']
y.head()
# Out:
# 0    82.74
# 1    40.24
# 2    35.82
# 3    33.00
# 4    31.37
# Name: Global_Sales, dtype: float64

# %%
#label encoding
from sklearn.preprocessing import LabelEncoder
le=LabelEncoder()
x.Name=le.fit_transform(x.Name)
x.Platform=le.fit_transform(x.Platform)
x.Genre=le.fit_transform(x.Genre)
x.head()
# Out:
#    Rank   Name  Platform    Year  Genre  NA_Sales  EU_Sales  JP_Sales  \
# 0     1  11007        26  2006.0     10     41.49     29.02      3.77
# 1     2   9327        11  1985.0      4     29.08      3.58      6.81
# 2     3   5573        26  2008.0      6     15.85     12.88      3.79
# 3     4  11009        26  2009.0     10     15.75     11.01      3.28
# 4     5   7346         5  1996.0      7     11.27      8.89     10.22
#
#    Other_Sales
# 0         8.46
# 1         0.77
# 2         3.31
# 3         2.96
# 4         1.00

# %%
#feature scaling
from sklearn.preprocessing import MinMaxScaler
ms=MinMaxScaler()
x_scaled=pd.DataFrame(ms.fit_transform(x),columns=x.columns)

# %%
x_scaled.head()
# Out:
#        Rank      Name  Platform   Year     Genre  NA_Sales  EU_Sales  \
# 0  0.000000  0.957797  0.866667  0.650  0.909091  1.000000  1.000000
# 1  0.000060  0.811608  0.366667  0.125  0.363636  0.700892  0.123363
# 2  0.000120  0.484946  0.866667  0.700  0.545455  0.382020  0.443832
# 3  0.000181  0.957971  0.866667  0.725  0.909091  0.379610  0.379394
# 4  0.000241  0.639227  0.166667  0.400  0.636364  0.271632  0.306340
#
#    JP_Sales  Other_Sales
# 0  0.368885     0.800378
# 1  0.666341     0.072848
# 2  0.370841     0.313150
# 3  0.320939     0.280038
# 4  1.000000     0.094607

# %%
#Splitting Data into Train and Test.
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=0)

# %%
x_train.shape,x_test.shape,y_train.shape,y_test.shape
# Out:
# ((13278, 9), (3320, 9), (13278,), (3320,))

# %% [markdown]
# # MACHINE LEARNINIG MODELS

# %% [markdown]
# ## LinearRegressor Model

# %%
from sklearn.linear_model import LinearRegression
lr=LinearRegression()

# %%
lr.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
pred = lr.predict(x_test)

# %%
pred
# Out:
# array([ 1.24962454,  0.35006686,  0.28031528, ...,  0.4799281 ,
#         0.35008567, 29.00936038])

# %%
lr.predict(ms.transform([[1,11007,26,2006.0, 10,41.49,29.02,3.77,8.46]]))
# Out:
# C:\ProgramData\anaconda3\Lib\site-packages\sklearn\base.py:439: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# C:\ProgramData\anaconda3\Lib\site-packages\sklearn\base.py:439: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([3.20127923])

# %% [markdown]
# #### Evaluation Metrics for the LinearRegression Model

# %%
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score

# %%
mae = mean_absolute_error(y_test, pred)
mse = mean_squared_error(y_test, pred)
rmse = mean_squared_error(y_test, pred, squared=False)  # RMSE is the square root of MSE
r2 = r2_score(y_test, pred)

print("Mean Absolute Error:", mae)
print("Mean Squared Error:", mse)
print("Root Mean Squared Error:", rmse)
print("R-squared:", r2)
# Out:
# Mean Absolute Error: 0.0029804823736235496
# Mean Squared Error: 2.6842205913422965e-05
# Root Mean Squared Error: 0.005180946430279217
# R-squared: 0.9999880111564263

# %% [markdown]
# ## DecisionTreeRegressor

# %%
from sklearn.tree import DecisionTreeRegressor
dtr = DecisionTreeRegressor()

# %%
dtr.fit(x_train,y_train)
# Out:
# DecisionTreeRegressor()

# %%
y_pred = dtr.predict(x_test)

# %%
y_test
# Out:
# 1586     1.25
# 5368     0.34
# 6275     0.27
# 9130     0.14
# 5759     0.31
#         ...
# 1911     1.08
# 4944     0.39
# 4110     0.48
# 5291     0.35
# 7       29.02
# Name: Global_Sales, Length: 3320, dtype: float64

# %%
dtr.predict(ms.transform([[1,11007,26,2006.0, 10,41.49,29.02,3.77,8.46]]))
# Out:
# C:\ProgramData\anaconda3\Lib\site-packages\sklearn\base.py:439: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# C:\ProgramData\anaconda3\Lib\site-packages\sklearn\base.py:439: UserWarning: X does not have valid feature names, but DecisionTreeRegressor was fitted with feature names
#   warnings.warn(
# array([35.82])

# %% [markdown]
# #### Evaluation Metrics for the Decisiontree model

# %%
mae = mean_absolute_error(y_test, y_pred)
mse = mean_squared_error(y_test, y_pred)
rmse = mean_squared_error(y_test, y_pred, squared=False)  # RMSE is the square root of MSE
r2 = r2_score(y_test, y_pred)

print("Mean Absolute Error:", mae)
print("Mean Squared Error:", mse)
print("Root Mean Squared Error:", rmse)
print("R-squared:", r2)
# Out:
# Mean Absolute Error: 0.005033132530120762
# Mean Squared Error: 0.01314346385542168
# Root Mean Squared Error: 0.11464494692493726
# R-squared: 0.9941295833625866

# %% [markdown]
# ## RandomForest Classifier

# %%
from sklearn.ensemble import RandomForestClassifier, RandomForestRegressor
rfr = RandomForestRegressor()

# %%
rfr.fit(x_train,y_train)
# Out:
# RandomForestRegressor()

# %%
R_pred = rfr.predict(x_test)

# %%
rfr.predict([[1,11007,26,2006.0, 10,41.49,29.02,3.77,8.46]])
# Out:
# C:\ProgramData\anaconda3\Lib\site-packages\sklearn\base.py:439: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# array([69.0276])

# %% [markdown]
# #### Evaluation Metrics for the RandomForest Regressor

# %%
mae = mean_absolute_error(y_test, R_pred)
mse = mean_squared_error(y_test, R_pred)
rmse = mean_squared_error(y_test, R_pred, squared=False)  # RMSE is the square root of MSE
r2 = r2_score(y_test, R_pred)

print("Mean Absolute Error:", mae)
print("Mean Squared Error:", mse)
print("Root Mean Squared Error:", rmse)
print("R-squared:", r2)
# Out:
# Mean Absolute Error: 0.003452981927711176
# Mean Squared Error: 0.006567515159638631
# Root Mean Squared Error: 0.08104020705574876
# R-squared: 0.9970666750649827
